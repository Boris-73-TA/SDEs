# %%
# pip install StochasticProcessSimulator

# %%
from StochasticProcessSimulator import StochasticProcessSimulator as SPS
simulator = SPS(
            process_type='GBM', do_plot=True)
paths = simulator.simulate()
# Out:
# Execution time:  0.39429283142089844
